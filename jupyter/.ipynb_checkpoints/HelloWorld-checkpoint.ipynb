# %%
import numpy as np
import pandas as pd

# %%
default = pd.read_csv('excel.csv', index_col="ANO")
type(default)

# Data
default.head()
# Out:
#              ENTIDAD  CLAVE MARCO GEOESTADISTICO NAL              MODALIDAD  \
# ANO
# 1997  AGUASCALIENTES                               1  DELITOS PATRIMONIALES
# 1997  AGUASCALIENTES                               1  DELITOS PATRIMONIALES
# 1997  AGUASCALIENTES                               1  DELITOS PATRIMONIALES
# 1997  AGUASCALIENTES                               1  DELITOS PATRIMONIALES
# 1997  AGUASCALIENTES                               1  DELITOS PATRIMONIALES
#
#                          TIPO                  SUBTIPO  ENERO  FEBRERO  MARZO  \
# ANO
# 1997       ABUSO DE CONFIANZA       ABUSO DE CONFIANZA     17       17     17
# 1997  DAÑO EN PROPIEDAD AJENA  DAÑO EN PROPIEDAD AJENA     45       45     45
# 1997                EXTORSION                EXTORSION      0        0      0
# 1997                   FRAUDE                   FRAUDE      9        9      9
# 1997                  DESPOJO            CON VIOLENCIA      0        0      0
#
# ...

# %%
# Size
default.shape
# Out:
# (20, 17)

# %%
# Column names
default.columns
# Out:
# Index(['ENTIDAD', 'CLAVE MARCO GEOESTADISTICO NAL', 'MODALIDAD', 'TIPO',
#        'SUBTIPO', 'ENERO', 'FEBRERO', 'MARZO', 'ABRIL', 'MAYO', 'JUNIO',
#        'JULIO', 'AGOSTO', 'SEPTIEMBRE', 'OCTUBRE', 'NOVIEMBRE', 'DICIEMBRE'],
#       dtype='object')

# %%
# Get a serie (file)

default['ENTIDAD']
# Out:
# ANO
# 1997         AGUASCALIENTES
# 1997         AGUASCALIENTES
# 1997         AGUASCALIENTES
# 1997         AGUASCALIENTES
# 1997         AGUASCALIENTES
# 1997    BAJA CALIFORNIA SUR
# 1997    BAJA CALIFORNIA SUR
# 1997    BAJA CALIFORNIA SUR
# 1997    BAJA CALIFORNIA SUR
# 1997    BAJA CALIFORNIA SUR
# 1997               COAHUILA
# 1997               COAHUILA
# 1997               COAHUILA
# 1997               COAHUILA
# 1997               COAHUILA
# 1997       CIUDAD DE MEXICO
# 1997       CIUDAD DE MEXICO
# 1997       CIUDAD DE MEXICO
# 1997       CIUDAD DE MEXICO
# 1997       CIUDAD DE MEXICO
# Name: ENTIDAD, dtype: object

# %%
default[['ENTIDAD', 'ENERO']]
# Out:
#                   ENTIDAD  ENERO
# ANO
# 1997       AGUASCALIENTES     17
# 1997       AGUASCALIENTES     45
# 1997       AGUASCALIENTES      0
# 1997       AGUASCALIENTES      9
# 1997       AGUASCALIENTES      0
# 1997  BAJA CALIFORNIA SUR      0
# 1997  BAJA CALIFORNIA SUR      0
# 1997  BAJA CALIFORNIA SUR      0
# 1997  BAJA CALIFORNIA SUR      0
# 1997  BAJA CALIFORNIA SUR      0
# 1997             COAHUILA      0
# 1997             COAHUILA    274
# 1997             COAHUILA      0
# 1997             COAHUILA     55
# 1997             COAHUILA      0
# 1997     CIUDAD DE MEXICO   6133
# 1997     CIUDAD DE MEXICO      2
# 1997     CIUDAD DE MEXICO     54
# 1997     CIUDAD DE MEXICO    532
# 1997     CIUDAD DE MEXICO   1643

# %%
default.loc[1997]
# Out:
#                   ENTIDAD  CLAVE MARCO GEOESTADISTICO NAL  \
# ANO
# 1997       AGUASCALIENTES                               1
# 1997       AGUASCALIENTES                               1
# 1997       AGUASCALIENTES                               1
# 1997       AGUASCALIENTES                               1
# 1997       AGUASCALIENTES                               1
# 1997  BAJA CALIFORNIA SUR                               3
# 1997  BAJA CALIFORNIA SUR                               3
# 1997  BAJA CALIFORNIA SUR                               3
# 1997  BAJA CALIFORNIA SUR                               3
# 1997  BAJA CALIFORNIA SUR                               3
# 1997             COAHUILA                               5
# 1997             COAHUILA                               5
# 1997             COAHUILA                               5
# 1997             COAHUILA                               5
# 1997             COAHUILA                               5
# ...

# %%
default['ENERO'].value_counts()
# Out:
# 0       10
# 55       1
# 54       1
# 6133     1
# 532      1
# 274      1
# 17       1
# 45       1
# 1643     1
# 9        1
# 2        1
# Name: ENERO, dtype: int64

# %%
# Mean
default['ENERO'].mean()
# Out:
# 438.19999999999999

# %%
# Standard Deviation
default['ENERO'].std()
# Out:
# 1392.4456561256377
